# %%
from azureml.core import Workspace, Experiment, ComputeTarget
from azureml.train.dnn import TensorFlow
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (pywin32 228 (c:\users\hehein\appdata\local\continuum\anaconda3\envs\embedded-ml-deployment\lib\site-packages), Requirement.parse('pywin32==227; sys_platform == "win32"'), {'docker'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (pywin32 228 (c:\users\hehein\appdata\local\continuum\anaconda3\envs\embedded-ml-deployment\lib\site-packages), Requirement.parse('pywin32==227; sys_platform == "win32"'), {'docker'}).

# %%
ws = Workspace.from_config()
# Out:
# ...
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
exp = Experiment(ws, "PredictSineTFLiteModel", _create_in_cloud=True)

# %%
# Estimator
compute_target = ComputeTarget(ws, "gpu-cluster")

# %%
from azureml.core.environment import Environment
from azureml.core.conda_dependencies import CondaDependencies

cd = CondaDependencies.create(conda_packages=["numpy"], pip_packages=["tensorflow==2.0", "matplotlib", "azureml-defaults", "inference-schema[numpy-support]"])

myenv = Environment(name="embedded-train")
myenv.docker.enabled = True
myenv.python.conda_dependencies = cd
myenv.docker.base_image = "251647e8dd28477dbb6ec50226f966fd.azurecr.io/embeddedbaseimage:latest"

# %%
estimator = TensorFlow("train", compute_target=compute_target, entry_script="train.py", script_params=None, environment_definition=myenv)
# Out:
# WARNING:azureml.train.estimator._framework_base_estimator:If environment_definition or conda_dependencies_file_path is specified, Azure ML will not install any framework related packages on behalf of the user.
# WARNING:azureml.train.estimator._framework_base_estimator:framework_version is not specified, defaulting to version 1.13.

# %%
run = exp.submit(estimator)
run.wait_for_completion(show_output=True, wait_post_processing=True)
# Out:
# WARNING:root:If 'script' has been provided here and a script file name has been specified in 'run_config', 'script' provided in ScriptRunConfig initialization will take precedence.
# RunId: PredictSineTFLiteModel_1603139411_2be1abc9
# Web View: https://ml.azure.com/experiments/PredictSineTFLiteModel/runs/PredictSineTFLiteModel_1603139411_2be1abc9?wsid=/subscriptions/147b095d-21d1-4446-b6ad-9c732cc7ce54/resourcegroups/embedded-ml-deployement/workspaces/embedded-ml-deployment
#
# Streaming azureml-logs/55_azureml-execution-tvmps_be3e24e93c951f88f8d753cc370a12eeb660901eebd02ef245b4092c276b2880_d.txt
# ...
#
# 2020-10-19T20:34:40Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-10-19T20:34:40Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2020-10-19T20:34:40Z Starting output-watcher...
# 2020-10-19T20:34:40Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# ...
